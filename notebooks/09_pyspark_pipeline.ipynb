# %% [markdown]
# # 09 — PySpark Feature Pipeline (Databricks)
#
# **Purpose:** Implement the same feature engineering pipeline in PySpark with medallion architecture (Bronze→Silver→Gold). Run on Databricks Free Edition.
#
# ---
#
# **Steps:**
# 1. Upload UCI II data to Databricks DBFS
# 2. Bronze layer: raw ingest, schema enforcement
# 3. Silver layer: cleaning (negative prices, type coercion, C-prefix flag)
# 4. Gold layer: customer-level behavioral features (same logic as src/features.py)
# 5. Validate: spot-check 10 customers against Pandas output for parity
# 6. Demo: show PySpark aggregation with window functions
# 7. Publish notebook link for README
# 8. **Note:** Run this on Databricks, not locally. This file is a reference / export.

# %%
# Run from repo root: jupyter notebook
import sys, os
sys.path.insert(0, os.path.abspath('..'))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.rcParams['figure.figsize'] = (12, 5)
sns.set_theme(style='darkgrid')
